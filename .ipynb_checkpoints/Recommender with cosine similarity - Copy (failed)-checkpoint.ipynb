# %%
import pandas as pd

path="D:/H&M dataset/transactions_train.csv"

df=pd.read_csv(path)
df
# Out:
#                t_dat                                        customer_id  \
# 0         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 3         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 4         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ...              ...                                                ...
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id
# 0          663713001  0.050831                 2
# 1          541518023  0.030492                 2
# 2          505221004  0.015237                 2
# 3          685687003  0.016932                 2
# 4          685687004  0.016932                 2
# ...              ...       ...               ...
# 31788319   929511001  0.059305                 2
# 31788320   891322004  0.042356                 2
# 31788321   918325001  0.043203                 1
# 31788322   833459002  0.006763                 1
# 31788323   898573003  0.033881                 2
#
# [31788324 rows x 5 columns]

# %%
#df=df[:100]
df=df[["customer_id","article_id"]]
df
# Out:
#                                                 customer_id  article_id
# 0         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1         000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2         00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4         00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
# ...                                                     ...         ...
# 31788319  fff2282977442e327b45d8c89afde25617d00124d0f999...   929511001
# 31788320  fff2282977442e327b45d8c89afde25617d00124d0f999...   891322004
# 31788321  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...   918325001
# 31788322  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...   833459002
# 31788323  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...   898573003
#
# [31788324 rows x 2 columns]

# %%
path2="D:/H&M dataset/articles.csv"
df2=pd.read_csv(path2)
df2.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %%
df2=df2[["article_id","prod_name","product_type_name","product_group_name"]]
df2.head()
# Out:
#    article_id          prod_name product_type_name  product_group_name
# 0   108775015          Strap top          Vest top  Garment Upper body
# 1   108775044          Strap top          Vest top  Garment Upper body
# 2   108775051      Strap top (1)          Vest top  Garment Upper body
# 3   110065001  OP T-shirt (Idro)               Bra           Underwear
# 4   110065002  OP T-shirt (Idro)               Bra           Underwear

# %%
path3="D:/H&M dataset/customers.csv"
df3=pd.read_csv(path3)
df3.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %%
df3=df3['customer_id']
df3.head()
# Out:
# 0    00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1    0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2    000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3    00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4    00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
# Name: customer_id, dtype: object

# %%
result = pd.merge(df3,df2, on="customer_id")
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3f59372c57b8> in <module>
# ----> 1 result = pd.merge(df3,df2, on="article_id")
#       2 result
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1044                         right_keys.append(rk)
#    1045                     if lk is not None:
# -> 1046                         left_keys.append(left._get_label_or_level_values(lk))
#    1047                         join_names.append(lk)
#    1048                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'article_id'

# %%
data=result.groupby('customer_id').agg({'article_id':'first', 
          'prod_name': ', '.join, 
          'product_type_name': ', '.join, 
          'product_group_name': 'first' }).reset_index()

# %%
data["ids"]=[i for i in range(0,data.shape[0])]
data
# Out:
#                                                customer_id  article_id  \
# 0        00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...   656719005
# 1        0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...   377277001
# 2        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 3        00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...   732413001
# 4        00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...   634249005
# ...                                                    ...         ...
# 1362276  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...   253448003
# 1362277  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...   507909001
# 1362278  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...   573716039
# 1362279  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...   714790020
# 1362280  ffffd9ac14e89946416d80e791d064701994755c3ab686...   806050001
#
#                                                  prod_name  \
# 0        Serpente HW slim trouser, Mariette Blazer, Mar...
# 1        Svea Cropped Tank, Henry polo. (1), CORY CORD ...
# 2        Atlanta Push Body Harlow, Atlanta Push Body Ha...
# 3            PANORAMA sports bra, Panorama mid support bra
# 4        Hedwig essential, Jacket Slim, Jacket Slim, Mo...
# ...                                                    ...
# 1362276  OP Push Melbourne^, Spice Girl 3pk hipster, Sc...
# 1362277  Rebecca or Delphine shirt, Luna skinny RW, Lun...
# 1362278  Kanta slacks, Capone blazer campaign, SUPREME ...
# 1362279  Mom Fit Ultra HW, Money tee TVP, Liza thong co...
# 1362280                                   Ballet highshaft
#
#                                          product_type_name  \
# 0        Trousers, Blazer, Blazer, Jacket, Jacket, Hood...
# 1        Vest top, Sweater, Skirt, Skirt, Trousers, Dre...
# 2        Underwear body, Underwear body, Bra, Blouse, S...
# 3                                                 Bra, Bra
# 4        Blouse, Jacket, Jacket, Sweater, Bikini top, S...
# ...                                                    ...
# 1362276  Bra, Underwear bottom, Other accessories, Othe...
# 1362277  Shirt, Trousers, Trousers, Boots, T-shirt, T-s...
# 1362278  Trousers, Blazer, Leggings/Tights, Leggings/Ti...
# 1362279  Trousers, T-shirt, Underwear bottom, Dress, Dr...
# 1362280                                              Boots
#
#          product_group_name      ids
# 0        Garment Lower body        0
# 1        Garment Upper body        1
# 2                 Underwear        2
# 3                 Underwear        3
# 4        Garment Upper body        4
# ...                     ...      ...
# 1362276           Underwear  1362276
# 1362277  Garment Upper body  1362277
# 1362278  Garment Lower body  1362278
# 1362279  Garment Lower body  1362279
# 1362280               Shoes  1362280
#
# [1362281 rows x 6 columns]

# %%
def important_features(dataset):
    data=dataset.copy()
    for i in range(0, dataset.shape[0]):
        data["imp"]=data["prod_name"]+' '+data["product_type_name"]+" "+data["product_group_name"]
    return data

# %%
data=important_features(result)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-135fb70d01c8> in <module>
# ----> 1 data=important_features(result)
#       2 data.head()
#
# <ipython-input-35-224598bc715b> in important_features(dataset)
#       2     data=dataset.copy()
#       3     for i in range(0, dataset.shape[0]):
# ----> 4         data["imp"]=data["prod_name"]+' '+data["product_type_name"]+" "+data["product_group_name"]
#       5     return data
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      87     @unpack_zerodim_and_defer("__add__")
#      88     def __add__(self, other):
# ---> 89         return self._arith_method(other, operator.add)
#      90
#      91     @unpack_zerodim_and_defer("__radd__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
# -> 5000         return self._construct_result(result, name=res_name)
#    5001
#    5002
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _construct_result(self, result, name)
#    2761         # We do not pass dtype to ensure that the Series constructor
#    2762         #  does inference in the case where `result` has object-dtype.
# -> 2763         out = self._constructor(result, index=self.index)
#    2764         out = out.__finalize__(self)
#    2765
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     362                     data = data.copy()
#     363             else:
# --> 364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
#     366                 data = SingleBlockManager.from_array(data, index)
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     546         if is_object_dtype(subarr.dtype) and not is_object_or_str_dtype:
#     547             inferred = lib.infer_dtype(subarr, skipna=False)
# --> 548             if inferred in {"interval", "period"}:
#     549                 subarr = array(subarr)
#     550
#
# KeyboardInterrupt:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
vec=TfidfVectorizer()

# %%
vecs=vec.fit_transform(data["imp"].apply(lambda x: np.str_(x)))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim=cosine_similarity(vecs)

# %%
sim[0][0]
# Out:
# 1.0000000000000002

# %%
def recommend(title):
    product_id=data[data.prod_name==title]["ids"].values[0]
    scores=list(enumerate(sim[product_id]))
    sorted_scores=sorted(scores,key=lambda x:x[1],reverse=True)
    sorted_scores=sorted_scores[1:]
    products=[data[products[0]==data["ids"]]["article_id"].values[0] for products in sorted_scores]
    return products

# %%
def recommend_ten(prod_list):
    first_ten=[]
    count=0
    for prod in prod_list:
        if count > 9:
            break
        count+=1
        first_ten.append(prod)
    return first_ten

# %%
column_names = ["customer_id","prediction"]

answer = pd.DataFrame(columns = column_names)

answer.head()
# Out:
# Empty DataFrame
# Columns: [customer_id, prediction]
# Index: []

# %%
data.drop_duplicates(subset=['customer_id'])
data
# Out:
#                                           customer_id  article_id  \
# 0   000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1   00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 2   00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...   688873012
# 3   0008968c0d451dbc5a9968da03196fe20051965edde741...   531310002
# 4   000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...   501820043
# 5   001127bffdda108579e6cb16080440e89bf1250a776c6e...   397068015
# 6   001ea4e9c54f7e9c88811260d954edc059d596147e1cf8...   652075001
# 7   001fd23db1109a94bba1319bb73df0b479059027c182da...   631744002
# 8   0021da829b898f82269fc51feded4eac2129058ee95bd7...   649356002
# 9   00228762ecff5b8d1ea6a2e52b96dafa198febddbc3bf3...   688545001
# 10  002b3c0a44a22c45a8d62ea9d2b88d1a89e335f8b84003...   673531001
# 11  003ac6eff3ca20cbe4e14a106a5e28b7551616005de8f9...   617322003
# 12  00401a367c5ac085cb9d4b77c56f3edcabf25153615db9...   613456009
# 13  00402f4463c8dc1b3ee54abfdea280e96cd87320449eca...   507909001
# 14  0045c79125b4dc958579f902b49eacd8598f9eeaa12205...   211143037
# 15  004888668b9458668aa3234d17337671673599f7f84d36...   662857005
# 16  0051a1d00ec9a4ff1a2f9aa32a4bb054cc9ba08e80be59...   640174002
# 17  005c9fb2ba6c49b2098a662f64a9124ef95cbec5fcf4eb...   625939005
# 18  00609a1cc562140fa87a6de432bef9c9f0b936b259ad30...   611415005
# 19  00708c3da4d07706d4cad77c6aecc1b1ce33d21d73022c...   255396006
# 20  0074c5948b6c96e7522f6f5c034b46cf08875b9a81c557...   524825010
# 21  00761aefe07a2dd6ca110c99f3856ede55f20ff00ce754...   634015003
# 22  0077ba345ef6aa8781802107df25bbb8a14fdcd04130c3...   534795002
# 23  00796ce0bc561897e7047a7b059867aa6424f63ec597e1...   659550001
# 24  007e4c2e0994b4aac97c2713d5dc0b7497d74113f32446...   547752003
# 25  007ea762fbbebfad288a49f1d8f7c2c0c62b189a8816fa...   610671001
#
#                                             prod_name  \
# 0   Atlanta Push Body Harlow, Rae Push (Melbourne) 2p
# 1   Inca Jumper, W YODA KNIT OL OFFER, W YODA KNIT...
# 2   Gyda!, Thomas paperbag wide, Fiona Wide, Gyda!...
# 3                       Drew Cardigan, Lauper Sweater
# 4   SIRPA, SIRPA, Felicia Tank, EDC ROMAN BLOUSE, ...
# 5                              Skinny L.W Bargain (1)
# 6                       Stork fancy, CSP Hackney tank
# 7         Mini Trainer 5p Socks, Space 5 pkt tregging
# 8   Håkan half zip CC, Dawn trousrer, TVP Henry tr...
# 9                                 SC - MAJOR boot low
# 10  Keyring fluff, Greta Shortie (Daisy Mid) 3p, G...
# 11  HM+ Glans tunic, HM+ Glans tunic, Glans SS, ED...
# 12  Valentino, A-band unicorn PU, HM+ Katie skated...
# 13             Rebecca or Delphine shirt, Swift Dress
# 14  Janet SL-set (W), Janet SL-set (W), India PJ (...
# 15                                        Cindererlla
# 16                                       Lola Lace-Up
# 17  Cat Tee, Irma SL-set print (J), Polly pencil c...
# 18  Charlotte Brazilian Aza.Low 2p, Liza Superpush...
# 19        Nora Cardigan, Dolly hood, Jess oversize LS
# 20                                   Latte slacks (1)
# 21  FOG tanktop, MIST muscle tank, Boulevard TOP P...
# 22                                            DOMINIC
# 23                                      lennart dress
# 24                                Slurp long tregging
# 25                                       Perrie trash
#
#                                     product_type_name  \
# 0                                 Underwear body, Bra
# 1         Sweater, Sweater, Sweater, Sweater, Sweater
# 2          Blouse, Trousers, Trousers, Blouse, Blouse
# 3                                   Cardigan, Sweater
# 4   Sweater, Sweater, Vest top, Blouse, Blouse, Sk...
# 5                                            Trousers
# 6                                   T-shirt, Vest top
# 7                                     Socks, Trousers
# 8               Sweater, Trousers, Trousers, Trousers
# 9                                               Boots
# 10  Other accessories, Underwear bottom, Underwear...
# 11                        Blouse, Blouse, Blouse, Top
# 12  Top, Hair/alice band, Dress, Pyjama jumpsuit/p...
# 13                                       Shirt, Dress
# 14     Pyjama set, Pyjama set, Pyjama set, Pyjama set
# 15                                            Sweater
# 16                                            Sweater
# 17                 T-shirt, Pyjama set, Bag, Bracelet
# 18  Underwear bottom, Bra, Sweater, Sweater, Under...
# 19                             Cardigan, Sweater, Top
# 20                                           Trousers
# 21                        Vest top, Vest top, T-shirt
# 22                                            Sweater
# 23                                              Dress
# 24                                           Trousers
# 25                                           Trousers
#
#                                    product_group_name  \
# 0                                Underwear, Underwear
# 1   Garment Upper body, Garment Upper body, Garmen...
# 2   Garment Upper body, Garment Lower body, Garmen...
# 3              Garment Upper body, Garment Upper body
# 4   Garment Upper body, Garment Upper body, Garmen...
# 5                                  Garment Lower body
# 6              Garment Upper body, Garment Upper body
# 7                  Socks & Tights, Garment Lower body
# 8   Garment Upper body, Garment Lower body, Garmen...
# 9                                               Shoes
# 10                  Accessories, Underwear, Underwear
# 11  Garment Upper body, Garment Upper body, Garmen...
# 12  Garment Upper body, Accessories, Garment Full ...
# 13              Garment Upper body, Garment Full body
# 14         Nightwear, Nightwear, Nightwear, Nightwear
# 15                                 Garment Upper body
# 16                                 Garment Upper body
# 17  Garment Upper body, Nightwear, Accessories, Ac...
# 18  Underwear, Underwear, Garment Upper body, Garm...
# 19  Garment Upper body, Garment Upper body, Garmen...
# 20                                 Garment Lower body
# 21  Garment Upper body, Garment Upper body, Garmen...
# 22                                 Garment Upper body
# 23                                  Garment Full body
# 24                                 Garment Lower body
# 25                                 Garment Lower body
#
#                                                   imp  ids
# 0   Atlanta Push Body Harlow Underwear body Underwear    0
# 1              Inca Jumper Sweater Garment Upper body    1
# 2                     Gyda! Blouse Garment Upper body    2
# 3           Drew Cardigan Cardigan Garment Upper body    3
# 4                    SIRPA Sweater Garment Upper body    4
# 5   Skinny L.W Bargain (1) Trousers Garment Lower ...    5
# 6              Stork fancy T-shirt Garment Upper body    6
# 7          Mini Trainer 5p Socks Socks Socks & Tights    7
# 8        Håkan half zip CC Sweater Garment Upper body    8
# 9                     SC - MAJOR boot low Boots Shoes    9
# 10        Keyring fluff Other accessories Accessories   10
# 11          HM+ Glans tunic Blouse Garment Upper body   11
# 12                   Valentino Top Garment Upper body   12
# 13  Rebecca or Delphine shirt Shirt Garment Upper ...   13
# 14              Janet SL-set (W) Pyjama set Nightwear   14
# 15             Cindererlla Sweater Garment Upper body   15
# 16            Lola Lace-Up Sweater Garment Upper body   16
# 17                 Cat Tee T-shirt Garment Upper body   17
# 18  Charlotte Brazilian Aza.Low 2p Underwear botto...   18
# 19          Nora Cardigan Cardigan Garment Upper body   19
# 20       Latte slacks (1) Trousers Garment Lower body   20
# 21            FOG tanktop Vest top Garment Upper body   21
# 22                 DOMINIC Sweater Garment Upper body   22
# 23              lennart dress Dress Garment Full body   23
# 24    Slurp long tregging Trousers Garment Lower body   24
# 25           Perrie trash Trousers Garment Lower body   25

# %%
answer['customer_id']=data['customer_id']
answer.head()
# Out:
#                                          customer_id prediction
# 0  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...        NaN
# 1  00007d2de826758b65a93dd24ce629ed66842531df6699...        NaN
# 2  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...        NaN
# 3  0008968c0d451dbc5a9968da03196fe20051965edde741...        NaN
# 4  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...        NaN

# %%
for i in range(26):
    products=recommend(data.prod_name[i])
    answer["prediction"][i]=recommend_ten(products)

# %%
answer.head()
# Out:
#                                          customer_id  \
# 0  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 2  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...
# 3  0008968c0d451dbc5a9968da03196fe20051965edde741...
# 4  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...
#
#                                           prediction
# 0  [611415005, 501820043, 662857005, 534795002, 6...
# 1  [501820043, 662857005, 534795002, 640174002, 6...
# 2  [617322003, 501820043, 662857005, 534795002, 6...
# 3  [255396006, 501820043, 662857005, 534795002, 6...
# 4  [662857005, 534795002, 505221004, 640174002, 6...

# %%
answer.to_csv('answer.csv')

# %%
import pandas as pd

# %%
path="D:/H&M dataset/articles.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %%
df=df[:100]

# %%
def important_features(dataset):
    data=dataset.copy()
    for i in range(0, dataset.shape[0]):
        data["imp"]=data["prod_name"]+' '+data["product_type_name"]+" "+data["product_group_name"]
    return data

# %%
data=important_features(df)
data.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    index_code        index_name  index_group_no index_group_name  section_no  \
# 0           A        Ladieswear               1       Ladieswear          16
# 1           A        Ladieswear               1       Ladieswear          16
# 2           A        Ladieswear               1       Ladieswear          16
# 3           B  Lingeries/Tights               1       Ladieswear          61
# 4           B  Lingeries/Tights               1       Ladieswear          61
#
#              section_name garment_group_no garment_group_name  \
# 0  Womens Everyday Basics             1002       Jersey Basic
# 1  Womens Everyday Basics             1002       Jersey Basic
# 2  Womens Everyday Basics             1002       Jersey Basic
# 3         Womens Lingerie             1017  Under-, Nightwear
# 4         Womens Lingerie             1017  Under-, Nightwear
#
#                                          detail_desc  \
# 0            Jersey top with narrow shoulder straps.
# 1            Jersey top with narrow shoulder straps.
# 2            Jersey top with narrow shoulder straps.
# 3  Microfibre T-shirt bra with underwired, moulde...
# 4  Microfibre T-shirt bra with underwired, moulde...
#
#                                          imp
# 0      Strap top Vest top Garment Upper body
# 1      Strap top Vest top Garment Upper body
# 2  Strap top (1) Vest top Garment Upper body
# 3            OP T-shirt (Idro) Bra Underwear
# 4            OP T-shirt (Idro) Bra Underwear
#
# [5 rows x 26 columns]

# %%
data["ids"]=[i for i in range(0,data.shape[0])]

# %%
data.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#          index_name index_group_no  index_group_name section_no  \
# 0        Ladieswear              1        Ladieswear         16
# 1        Ladieswear              1        Ladieswear         16
# 2        Ladieswear              1        Ladieswear         16
# 3  Lingeries/Tights              1        Ladieswear         61
# 4  Lingeries/Tights              1        Ladieswear         61
#
#              section_name garment_group_no garment_group_name  \
# 0  Womens Everyday Basics             1002       Jersey Basic
# 1  Womens Everyday Basics             1002       Jersey Basic
# 2  Womens Everyday Basics             1002       Jersey Basic
# 3         Womens Lingerie             1017  Under-, Nightwear
# 4         Womens Lingerie             1017  Under-, Nightwear
#
#                                          detail_desc  \
# 0            Jersey top with narrow shoulder straps.
# 1            Jersey top with narrow shoulder straps.
# 2            Jersey top with narrow shoulder straps.
# 3  Microfibre T-shirt bra with underwired, moulde...
# 4  Microfibre T-shirt bra with underwired, moulde...
#
#                                          imp ids
# 0      Strap top Vest top Garment Upper body   0
# 1      Strap top Vest top Garment Upper body   1
# 2  Strap top (1) Vest top Garment Upper body   2
# 3            OP T-shirt (Idro) Bra Underwear   3
# 4            OP T-shirt (Idro) Bra Underwear   4
#
# [5 rows x 27 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
vec=TfidfVectorizer()

# %%
vecs=vec.fit_transform(data["imp"].apply(lambda x: np.str_(x)))

# %%
vecs.shape
# Out:
# (100, 97)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim=cosine_similarity(vecs)

# %%
sim[0][72]
# Out:
# 0.07412048510127216

# %%
def recommend(title):
    product_id=data[data.prod_name==title]["ids"].values[0]
    scores=list(enumerate(sim[product_id]))
    sorted_scores=sorted(scores,key=lambda x:x[1],reverse=True)
    sorted_scores=sorted_scores[1:]
    products=[data[products[0]==data["ids"]]["prod_name"].values[0] for products in sorted_scores]
    return products

# %%
def recommend_ten(prod_list):
    first_ten=[]
    count=0
    for prod in prod_list:
        if count > 9:
            break
        count+=1
        first_ten.append(prod)
    return first_ten

# %%
lst=recommend('Strap top')
m=recommend_ten(lst)
m
# Out:
# ['Strap top',
#  'Strap top (1)',
#  'Dorian l/s basic',
#  'KOMPIS 2-pack L/S',
#  'KOMPIS 2-pack L/S',
#  'Frugan longsleeve',
#  'Control Top 50 den 1p Tights',
#  '3P TANKTOP BODY',
#  'Dorian l/s basic',
#  'Dorian l/s basic']
